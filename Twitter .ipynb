# %%
#Twitter Credentials 
consumer_key = 'JN2Ax1netJVkZlmOdxNjuDv6U'
consumer_secret = 'Ck80Dyt4pznsbRQ7KN4jcva0fsm51MDcQmx3nepWoMxkstqBSj'
access_token = '206616022-wXaBsUWbVe5oojulDHh0WgeSm1k6CileqCFSu4IW'
access_token_secret = '8gHmiUrfdTcJcUPbpr0NKNaqLkeevg8cIZ0T0kykPMQMY'

# %%
import tweepy #Twitter API

# %%
import csv

# %%
import textblob #For sentiment analysis

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
user=api.me()
print(user.name)
# Out:
# RAJESH SHANMUGAM

# %%
csvFile = open('ua.csv', 'a')
csvWriter = csv.writer(csvFile)

# %%
for tweet in tweepy.Cursor(api.search,q="today",count=10,
                           lang="en").items():
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# 2018-08-15 14:42:43 RT @Protodude: Today is the only day you can RT this. https://t.co/LodtM9Ij0L
# 2018-08-15 14:42:43 The @SAfH_Maternity team in attendance today at the Introduction to project: Mum Bub Hub (MBH) Improving access to… https://t.co/ov2Sm5vf1n
# 2018-08-15 14:42:42 Today at Walton TransCan! Catch all the action!
#
# Motos run from 7:50am to 6:40pm.
#
# Social Activity Tonight at 7pm… https://t.co/4UbA56Fs8v
# 2018-08-15 14:42:42 My baby 💛 My son 👩‍👦 My twin 😩 is turning 6 today 💆🏾‍♀️ I’m stressed out and I just want you to go back to being a… https://t.co/W8mYUMMHHL
# 2018-08-15 14:42:42 RT @Lawrence: Today's lesson for racists:
#
# Using the word dog instead of the N-word does NOT prove you are not a racist.
# 2018-08-15 14:42:42 RT @heathercampbell: 106 years ago today. https://t.co/aXST5LVQjb
# 2018-08-15 14:42:42 RT @ColleenB123: Hi. I hate today. For no particular reason. I just hate it. ✌🏻
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-23-f24fec7aede6> in <module>()
#       1 for tweet in tweepy.Cursor(api.search,q="today",count=10,
# ----> 2                            lang="en").items():
#       3     print (tweet.created_at, tweet.text)
#       4     csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# ~\Anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
# ...
